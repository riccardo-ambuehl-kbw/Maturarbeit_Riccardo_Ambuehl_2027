# %% [markdown]
# # 01 Daten laden
#
# Dieses Notebook nutzt künstliche Platzhalterdaten und benötigt keine externen APIs.

# %%
import pandas as pd

preise = pd.DataFrame({
    "datum": pd.date_range("2020-01-01", periods=6, freq="YE"),
    "ETF_Global": [100, 112, 106, 121, 133, 145],
    "Aktie_A": [100, 125, 91, 137, 149, 172],
    "Anleihe_B": [100, 103, 101, 105, 108, 111],
})

preise
# Out:
#        datum  ETF_Global  Aktie_A  Anleihe_B
# 0 2020-12-31         100      100        100
# 1 2021-12-31         112      125        103
# 2 2022-12-31         106       91        101
# 3 2023-12-31         121      137        105
# 4 2024-12-31         133      149        108
# 5 2025-12-31         145      172        111

# %%
renditen = preise.set_index("datum").pct_change().dropna()
renditen
# Out:
#             ETF_Global   Aktie_A  Anleihe_B
# datum
# 2021-12-31    0.120000  0.250000   0.030000
# 2022-12-31   -0.053571 -0.272000  -0.019417
# 2023-12-31    0.141509  0.505495   0.039604
# 2024-12-31    0.099174  0.087591   0.028571
# 2025-12-31    0.090226  0.154362   0.027778
